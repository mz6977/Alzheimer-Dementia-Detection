# %% [markdown]
# # Imports

# %%
# Standard libraries
import random
from collections import Counter

# External libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import auc, classification_report, confusion_matrix, roc_curve
from sklearn.model_selection import train_test_split

# TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Directories

# %%
## Set Path Here before running the code
WORKING_DIRECTORY =  "./data/Dataset"

##  Name of classes 
CLASSES = ['Mild-Demented',
           'Moderate-Demented',
           'Non-Demented',
           'VeryMild-Demented']

# %% [markdown]
# # Load img, Rescale, One Hot Encoding

# %%
X, y = [], []

## Images rescaling
datagen = ImageDataGenerator(rescale=1.0/255.0)

#   Load images by resizing and shuffling randomly
train_dataset = datagen.flow_from_directory(WORKING_DIRECTORY, target_size=(176, 208),batch_size=6400, shuffle=True)

### Seperate Dataset from  Data Genrator
X, y = train_dataset.next()
# Out:
# Found 6426 images belonging to 4 classes.

# %%
samples_before = len(X)
print("Images shape :\t", X.shape)
print("Labels shape :\t", y.shape)
# Out:
# Images shape :	 (6400, 176, 208, 3)
# Labels shape :	 (6400, 4)

# %%
#   Number of samples in classes 
print("Number of samples in each class:\t", sorted(Counter(np.argmax(y, axis=1)).items()))

#   class labels as per indices
print("Classes Names according to index:\t", train_dataset.class_indices)
# Out:
# Number of samples in each class:	 [(0, 894), (1, 89), (2, 3184), (3, 2233)]
# Classes Names according to index:	 {'Mild_Demented': 0, 'Moderate_Demented': 1, 'Non_Demented': 2, 'Very_Mild_Demented': 3}

# %% [markdown]
# # random samples of original dataset

# %%
fig = plt.figure(figsize=(10,8))

rows = 4
columns = 4

for i in range(rows * columns):
    fig.add_subplot(rows, columns, i+1)
    num = random.randint(0, len(X)-1 )
    plt.imshow(X[num])
    plt.axis('off')
    plt.title(CLASSES[(np.argmax(y[num]))], fontsize=8)
plt.axis('off')
plt.show()

# %% [markdown]
# # Split Dataset

# %%
#   20% split to validation and 80% split to train set
X_train, x_val, y_train, y_val = train_test_split(X,y, test_size = 0.2)

#   20% split to test from 80% of train and 60% remains in train set
X_train, x_test, y_train, y_test = train_test_split(X_train,y_train, test_size = 0.2)

# Number of samples after train test split
print("Number of samples after splitting into Training, validation & test set\n")

print("Train     \t",sorted(Counter(np.argmax(y_train, axis=1)).items()))
print("Validation\t",sorted(Counter(np.argmax(y_val, axis=1)).items()))
print("Test      \t",sorted(Counter(np.argmax(y_test, axis=1)).items()))
# Out:
# Number of samples after splitting into Training, validation & test set
#
# Train     	 [(0, 572), (1, 62), (2, 2064), (3, 1398)]
# Validation	 [(0, 192), (1, 16), (2, 611), (3, 461)]
# Test      	 [(0, 130), (1, 11), (2, 509), (3, 374)]

# %%
del X, y       #### NO MORE NEEDED

# %% [markdown]
# # Train Model

# %%
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(176, 208, 3))

# Create a new model on top of the base VGG19 model
model = Sequential()

# Add the VGG19 base model
model.add(base_model)

model.add(Dropout(0.10))

model.add(Flatten())

model.add(BatchNormalization())
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.30))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.30))

model.add(Dense(4, activation='softmax'))

base_model.summary()

model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 176, 208, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 176, 208, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 176, 208, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 88, 104, 64)       0
#
#  block2_conv1 (Conv2D)       (None, 88, 104, 128)      73856
#
#  block2_conv2 (Conv2D)       (None, 88, 104, 128)      147584
#
#  block2_pool (MaxPooling2D)  (None, 44, 52, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 44, 52, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 44, 52, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 44, 52, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 44, 52, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 26, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 26, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 26, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 26, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 22, 26, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 13, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 13, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 13, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 13, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 11, 13, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 6, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 5, 6, 512)         20024384
#
#  dropout (Dropout)           (None, 5, 6, 512)         0
#
#  flatten (Flatten)           (None, 15360)             0
#
#  batch_normalization (BatchN  (None, 15360)            61440
#  ormalization)
#
#  dense (Dense)               (None, 2048)              31459328
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 53,647,428
# Trainable params: 53,616,708
# Non-trainable params: 30,720
# _________________________________________________________________

# %%
### Model Compilation
model.compile(
    optimizer=SGD(learning_rate=0.01), 
    loss = tf.keras.losses.CategoricalCrossentropy(name='loss'), 
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='acc'), 
        tf.keras.metrics.AUC(name='auc'),
        tf.metrics.Precision(name="precision"),
        tf.metrics.Recall(name="recall") 
       ])

# %%
# callbacks used in model to perform well
rop_callback = ReduceLROnPlateau(monitor="val_loss", patience=2)

CALLBACKS = [rop_callback]

# %%
#   declare to run on small gpu create batch sizes of images
valAug = ImageDataGenerator()

#   defining batch size
batch_size = 8

history = model.fit(valAug.flow(X_train, y_train, batch_size=batch_size, shuffle = True),
steps_per_epoch=len(X_train) // batch_size,
validation_data=valAug.flow(x_val, y_val, batch_size=batch_size, shuffle = True),
validation_steps=len(x_test) // batch_size,
epochs= 30,
batch_size=batch_size,
callbacks = CALLBACKS
)
# Out:
# Epoch 1/30
# 512/512 [==============================] - 40s 62ms/step - loss: 0.9887 - acc: 0.5303 - auc: 0.8159 - precision: 0.6027 - recall: 0.3748 - val_loss: 1.3534 - val_acc: 0.3516 - val_auc: 0.6551 - val_precision: 0.5161 - val_recall: 0.0469 - lr: 0.0100
# Epoch 2/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.9292 - acc: 0.5579 - auc: 0.8385 - precision: 0.6644 - recall: 0.4065 - val_loss: 1.8807 - val_acc: 0.4785 - val_auc: 0.8155 - val_precision: 0.4785 - val_recall: 0.4785 - lr: 0.0100
# Epoch 3/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.8876 - acc: 0.5837 - auc: 0.8529 - precision: 0.6792 - recall: 0.4326 - val_loss: 1.7278 - val_acc: 0.3594 - val_auc: 0.6422 - val_precision: 0.3471 - val_recall: 0.2881 - lr: 0.0100
# Epoch 4/30
# 512/512 [==============================] - 33s 64ms/step - loss: 0.8274 - acc: 0.6184 - auc: 0.8735 - precision: 0.7349 - recall: 0.4766 - val_loss: 0.9048 - val_acc: 0.5742 - val_auc: 0.8546 - val_precision: 0.6610 - val_recall: 0.3828 - lr: 1.0000e-03
# Epoch 5/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.8033 - acc: 0.6418 - auc: 0.8829 - precision: 0.7264 - recall: 0.5100 - val_loss: 1.1385 - val_acc: 0.5469 - val_auc: 0.8417 - val_precision: 0.5611 - val_recall: 0.5068 - lr: 1.0000e-03
# Epoch 6/30
# 512/512 [==============================] - 33s 64ms/step - loss: 0.7845 - acc: 0.6526 - auc: 0.8882 - precision: 0.7404 - recall: 0.5320 - val_loss: 1.0485 - val_acc: 0.4785 - val_auc: 0.8077 - val_precision: 0.5441 - val_recall: 0.3916 - lr: 1.0000e-03
# Epoch 7/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7662 - acc: 0.6663 - auc: 0.8947 - precision: 0.7551 - recall: 0.5474 - val_loss: 0.7773 - val_acc: 0.6904 - val_auc: 0.9107 - val_precision: 0.8579 - val_recall: 0.4482 - lr: 1.0000e-04
# Epoch 8/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7557 - acc: 0.6729 - auc: 0.8976 - precision: 0.7531 - recall: 0.5562 - val_loss: 0.9301 - val_acc: 0.6064 - val_auc: 0.8598 - val_precision: 0.7702 - val_recall: 0.3633 - lr: 1.0000e-04
# Epoch 9/30
# 512/512 [==============================] - 32s 62ms/step - loss: 0.7509 - acc: 0.6748 - auc: 0.8990 - precision: 0.7589 - recall: 0.5571 - val_loss: 0.7444 - val_acc: 0.6748 - val_auc: 0.9066 - val_precision: 0.7925 - val_recall: 0.4922 - lr: 1.0000e-04
# Epoch 10/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7604 - acc: 0.6675 - auc: 0.8966 - precision: 0.7491 - recall: 0.5532 - val_loss: 0.8259 - val_acc: 0.6797 - val_auc: 0.9050 - val_precision: 0.8574 - val_recall: 0.4229 - lr: 1.0000e-04
# Epoch 11/30
# 512/512 [==============================] - 32s 62ms/step - loss: 0.7380 - acc: 0.6865 - auc: 0.9034 - precision: 0.7642 - recall: 0.5706 - val_loss: 0.7787 - val_acc: 0.6934 - val_auc: 0.9113 - val_precision: 0.8503 - val_recall: 0.4492 - lr: 1.0000e-04
# Epoch 12/30
# 512/512 [==============================] - 32s 62ms/step - loss: 0.7394 - acc: 0.6760 - auc: 0.9017 - precision: 0.7594 - recall: 0.5664 - val_loss: 0.7992 - val_acc: 0.6836 - val_auc: 0.9105 - val_precision: 0.8633 - val_recall: 0.4502 - lr: 1.0000e-05
# Epoch 13/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7397 - acc: 0.6807 - auc: 0.9022 - precision: 0.7588 - recall: 0.5637 - val_loss: 0.8009 - val_acc: 0.6875 - val_auc: 0.9056 - val_precision: 0.8530 - val_recall: 0.4307 - lr: 1.0000e-05
# Epoch 14/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7406 - acc: 0.6731 - auc: 0.9015 - precision: 0.7548 - recall: 0.5623 - val_loss: 0.7871 - val_acc: 0.6787 - val_auc: 0.9073 - val_precision: 0.8505 - val_recall: 0.4443 - lr: 1.0000e-06
# Epoch 15/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7335 - acc: 0.6873 - auc: 0.9039 - precision: 0.7604 - recall: 0.5693 - val_loss: 0.7753 - val_acc: 0.6895 - val_auc: 0.9119 - val_precision: 0.8550 - val_recall: 0.4492 - lr: 1.0000e-06
# Epoch 16/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7389 - acc: 0.6748 - auc: 0.9020 - precision: 0.7578 - recall: 0.5676 - val_loss: 0.7736 - val_acc: 0.6982 - val_auc: 0.9130 - val_precision: 0.8499 - val_recall: 0.4590 - lr: 1.0000e-07
# Epoch 17/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7348 - acc: 0.6809 - auc: 0.9037 - precision: 0.7627 - recall: 0.5688 - val_loss: 0.7785 - val_acc: 0.6885 - val_auc: 0.9086 - val_precision: 0.8535 - val_recall: 0.4551 - lr: 1.0000e-07
# Epoch 18/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7395 - acc: 0.6829 - auc: 0.9023 - precision: 0.7572 - recall: 0.5674 - val_loss: 0.7812 - val_acc: 0.6865 - val_auc: 0.9073 - val_precision: 0.8396 - val_recall: 0.4551 - lr: 1.0000e-08
# Epoch 19/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7456 - acc: 0.6814 - auc: 0.9009 - precision: 0.7584 - recall: 0.5754 - val_loss: 0.7831 - val_acc: 0.6895 - val_auc: 0.9100 - val_precision: 0.8403 - val_recall: 0.4521 - lr: 1.0000e-08
# Epoch 20/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7400 - acc: 0.6875 - auc: 0.9027 - precision: 0.7611 - recall: 0.5725 - val_loss: 0.7738 - val_acc: 0.6846 - val_auc: 0.9100 - val_precision: 0.8464 - val_recall: 0.4629 - lr: 1.0000e-09
# Epoch 21/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7362 - acc: 0.6919 - auc: 0.9039 - precision: 0.7702 - recall: 0.5762 - val_loss: 0.7696 - val_acc: 0.6934 - val_auc: 0.9113 - val_precision: 0.8525 - val_recall: 0.4629 - lr: 1.0000e-09
# Epoch 22/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7353 - acc: 0.6890 - auc: 0.9040 - precision: 0.7675 - recall: 0.5754 - val_loss: 0.7856 - val_acc: 0.6895 - val_auc: 0.9067 - val_precision: 0.8370 - val_recall: 0.4414 - lr: 1.0000e-10
# Epoch 23/30
# 512/512 [==============================] - 33s 64ms/step - loss: 0.7437 - acc: 0.6802 - auc: 0.9009 - precision: 0.7554 - recall: 0.5676 - val_loss: 0.7782 - val_acc: 0.6855 - val_auc: 0.9100 - val_precision: 0.8455 - val_recall: 0.4541 - lr: 1.0000e-10
# Epoch 24/30
# 512/512 [==============================] - 33s 64ms/step - loss: 0.7359 - acc: 0.6792 - auc: 0.9036 - precision: 0.7653 - recall: 0.5708 - val_loss: 0.7879 - val_acc: 0.6846 - val_auc: 0.9079 - val_precision: 0.8379 - val_recall: 0.4492 - lr: 1.0000e-11
# Epoch 25/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7467 - acc: 0.6780 - auc: 0.9003 - precision: 0.7586 - recall: 0.5662 - val_loss: 0.7702 - val_acc: 0.6963 - val_auc: 0.9120 - val_precision: 0.8399 - val_recall: 0.4561 - lr: 1.0000e-11
# Epoch 26/30
# 512/512 [==============================] - 31s 60ms/step - loss: 0.7363 - acc: 0.6755 - auc: 0.9030 - precision: 0.7600 - recall: 0.5605 - val_loss: 0.7706 - val_acc: 0.6924 - val_auc: 0.9103 - val_precision: 0.8437 - val_recall: 0.4639 - lr: 1.0000e-12
# Epoch 27/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7394 - acc: 0.6846 - auc: 0.9020 - precision: 0.7639 - recall: 0.5686 - val_loss: 0.7824 - val_acc: 0.6855 - val_auc: 0.9071 - val_precision: 0.8370 - val_recall: 0.4463 - lr: 1.0000e-12
# Epoch 28/30
# 512/512 [==============================] - 32s 63ms/step - loss: 0.7412 - acc: 0.6785 - auc: 0.9018 - precision: 0.7645 - recall: 0.5681 - val_loss: 0.7643 - val_acc: 0.6934 - val_auc: 0.9134 - val_precision: 0.8516 - val_recall: 0.4707 - lr: 1.0000e-13
# Epoch 29/30
# 512/512 [==============================] - 30s 59ms/step - loss: 0.7398 - acc: 0.6846 - auc: 0.9023 - precision: 0.7668 - recall: 0.5659 - val_loss: 0.7735 - val_acc: 0.6836 - val_auc: 0.9085 - val_precision: 0.8405 - val_recall: 0.4580 - lr: 1.0000e-13
# Epoch 30/30
# 512/512 [==============================] - 30s 59ms/step - loss: 0.7304 - acc: 0.6841 - auc: 0.9047 - precision: 0.7685 - recall: 0.5664 - val_loss: 0.7818 - val_acc: 0.6865 - val_auc: 0.9060 - val_precision: 0.8400 - val_recall: 0.4512 - lr: 1.0000e-14

# %% [markdown]
# # Model Evaluation

# %%
test_scores = model.evaluate(x_test, y_test, batch_size = 32)

precision = test_scores[3]
recall = test_scores[4]

# Calculate F1-score
f1_score = 2 * (precision * recall) / (precision + recall)

print("Testing Accuracy: \t {0:0.6f} %".format(test_scores[1] * 100))
print("Testing AUC: \t\t {0:0.6f} %".format(test_scores[2] * 100))
print("Testing Precision: \t {0:0.6f} %".format(precision * 100))
print("Testing Recall: \t {0:0.6f} %".format(recall * 100))
print("Testing F1-Score: \t {0:0.6f} %".format(f1_score * 100))
# Out:
# 32/32 [==============================] - 3s 49ms/step - loss: 0.7569 - acc: 0.6982 - auc: 0.9158 - precision: 0.8418 - recall: 0.4521
# Testing Accuracy: 	 69.824219 %
# Testing AUC: 		 91.583580 %
# Testing Precision: 	 84.181815 %
# Testing Recall: 	 45.214844 %
# Testing F1-Score: 	 58.831003 %

# %% [markdown]
# # Graphs

# %%
plt.plot(history.history['acc'], 'b')
plt.plot(history.history['val_acc'], 'g')
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['loss'], 'b')
plt.plot(history.history['val_loss'], 'g')
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['auc'], 'b')
plt.plot(history.history['val_auc'], 'g')
plt.title("Model AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['precision'], 'b')
plt.plot(history.history['val_precision'], 'g')
plt.title("Model Precision")
plt.xlabel("Epochs")
plt.ylabel("Precision")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['recall'], 'b')
plt.plot(history.history['val_recall'], 'g')
plt.title("Model Recall")
plt.xlabel("Epochs")
plt.ylabel("Recall")
plt.legend(["train", "val"])
plt.show()

# %% [markdown]
# # Test Set Evaluation

# %%
pred_labels = model.predict(x_test, batch_size=32)

def roundoff(arr):
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

# Apply rounding to each set of predicted labels
rounded_pred_labels = [roundoff(labels) for labels in pred_labels]

print(classification_report(y_test, rounded_pred_labels, target_names=CLASSES))
# Out:
# 32/32 [==============================] - 1s 37ms/step
#                    precision    recall  f1-score   support
#
#     Mild-Demented       0.48      0.61      0.53       130
# Moderate-Demented       0.00      0.00      0.00        11
#      Non-Demented       0.78      0.78      0.78       509
# VeryMild-Demented       0.69      0.64      0.67       374
#
#         micro avg       0.70      0.70      0.70      1024
#         macro avg       0.49      0.51      0.49      1024
#      weighted avg       0.70      0.70      0.70      1024
#       samples avg       0.70      0.70      0.70      1024
# c:\Users\rajpu\anaconda3\envs\py310\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(y_test, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= CLASSES, yticklabels=CLASSES)

plt.title('Confusion Matrix of Model', fontweight='bold', fontsize=14.0)
plt.xlabel('Predictions', fontweight='bold', fontsize=13)
plt.ylabel('Ground Truth', fontweight='bold', fontsize=13)
plt.tight_layout()
plt.show(ax)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], pred_labels[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), pred_labels.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure()
lw = 2
plt.plot(
    fpr[2],
    tpr[2],
    color="darkorange",
    lw=lw,
    label="ROC curve (area = %0.4f)" % roc_auc[2])

plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic ")
plt.legend(loc="lower right")
plt.show()

# %%
n_classes = 4
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.4f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.4f})".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

for i in range(n_classes):
    plt.plot(
        fpr[i],
        tpr[i],
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.4f})".format(i, roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Some extension of Receiver operating characteristic to multiclass")
plt.legend(loc="lower right")
plt.show()

# %%
model.save('./VGG19_SGD_TRY1.h5')
