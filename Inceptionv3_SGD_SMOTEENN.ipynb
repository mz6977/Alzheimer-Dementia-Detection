# %% [markdown]
# # Imports

# %%
# Standard libraries
import random
from collections import Counter

# External libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from imblearn.combine import SMOTEENN
from sklearn.metrics import auc, classification_report, confusion_matrix, roc_curve
from sklearn.model_selection import train_test_split

# TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Directories

# %%
## Set Path Here before running the code
WORKING_DIRECTORY =  "./data/Dataset"

##  Name of classes 
CLASSES = ['Mild-Demented',
           'Moderate-Demented',
           'Non-Demented',
           'VeryMild-Demented']

# %% [markdown]
# # Load img, Rescale, One Hot Encoding

# %%
X, y = [], []

## Images rescaling
datagen = ImageDataGenerator(rescale=1.0/255.0)

#   Load images by resizing and shuffling randomly
train_dataset = datagen.flow_from_directory(WORKING_DIRECTORY, target_size=(176, 208),batch_size=6400, shuffle=True)

### Seperate Dataset from  Data Genrator
X, y = train_dataset.next()
# Out:
# Found 6426 images belonging to 4 classes.

# %%
samples_before = len(X)
print("Images shape :\t", X.shape)
print("Labels shape :\t", y.shape)
# Out:
# Images shape :	 (6400, 176, 208, 3)
# Labels shape :	 (6400, 4)

# %%
#   Number of samples in classes 
print("Number of samples in each class:\t", sorted(Counter(np.argmax(y, axis=1)).items()))

#   class labels as per indices
print("Classes Names according to index:\t", train_dataset.class_indices)
# Out:
# Number of samples in each class:	 [(0, 892), (1, 90), (2, 3189), (3, 2229)]
# Classes Names according to index:	 {'Mild_Demented': 0, 'Moderate_Demented': 1, 'Non_Demented': 2, 'Very_Mild_Demented': 3}

# %% [markdown]
# # random samples of original dataset

# %%
fig = plt.figure(figsize=(10,8))

rows = 4
columns = 4

for i in range(rows * columns):
    fig.add_subplot(rows, columns, i+1)
    num = random.randint(0, len(X)-1 )
    plt.imshow(X[num])
    plt.axis('off')
    plt.title(CLASSES[(np.argmax(y[num]))], fontsize=8)
plt.axis('off')
plt.show()

# %% [markdown]
# # Apply SmoteENN

# %%
#   reshaping the images to 1D
X = X.reshape(-1, 176 * 208 * 3)

#   Oversampling method to remove imbalance class problem
X, y = SMOTEENN().fit_resample(X, y)

#   reshape images to images size of 208, 176, 3
X = X.reshape(-1, 176, 208, 3)

samples_after = len(X)
print("Number of samples after SMOTEENN :\t", sorted(Counter(np.argmax(y, axis=1)).items()))
# Out:
# Number of samples after SMOTEENN :	 [(0, 3189), (1, 3189), (2, 3039), (3, 3168)]

# %% [markdown]
# # Random samples of generated data

# %%
fig = plt.figure(figsize=(10,8))

rows = 4
columns = 4

for i in range(rows * columns):
    fig.add_subplot(rows, columns, i+1)
    num = random.randint(samples_before, samples_after - 1 )
    plt.imshow(X[num])
    plt.axis('off')
    plt.title(CLASSES[(np.argmax(y[num]))], fontsize=8)
plt.axis('off')
plt.show()

# %% [markdown]
# # Split Dataset

# %%
#   20% split to validation and 80% split to train set
X_train, x_val, y_train, y_val = train_test_split(X,y, test_size = 0.2)

#   20% split to test from 80% of train and 60% remains in train set
X_train, x_test, y_train, y_test = train_test_split(X_train,y_train, test_size = 0.2)

# Number of samples after train test split
print("Number of samples after splitting into Training, validation & test set\n")

print("Train     \t",sorted(Counter(np.argmax(y_train, axis=1)).items()))
print("Validation\t",sorted(Counter(np.argmax(y_val, axis=1)).items()))
print("Test      \t",sorted(Counter(np.argmax(y_test, axis=1)).items()))
# Out:
# Number of samples after splitting into Training, validation & test set
#
# Train     	 [(0, 2046), (1, 2017), (2, 1941), (3, 2050)]
# Validation	 [(0, 630), (1, 652), (2, 608), (3, 627)]
# Test      	 [(0, 513), (1, 520), (2, 490), (3, 491)]

# %%
del X, y       #### NO MORE NEEDED

# %% [markdown]
# # Train Model

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(176, 208, 3))

# Create a new model on top of the base VGG19 model
model = Sequential()

# Add the VGG19 base model
model.add(base_model)

model.add(Dropout(0.10))

model.add(Flatten())

model.add(BatchNormalization())
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.30))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.30))

model.add(Dense(4, activation='softmax'))

base_model.summary()

model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 176, 208, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 87, 103, 32)  864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 87, 103, 32)  96         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 87, 103, 32)  0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 85, 101, 32)  9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 85, 101, 32)  96         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 85, 101, 32)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 85, 101, 64)  18432       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 85, 101, 64)  192        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 85, 101, 64)  0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 42, 50, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 42, 50, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 42, 50, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 42, 50, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 40, 48, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 40, 48, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 40, 48, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 19, 23, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 19, 23, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 19, 23, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 19, 23, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 19, 23, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 19, 23, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 19, 23, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 19, 23, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 19, 23, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 19, 23, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 19, 23, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 19, 23, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 19, 23, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 19, 23, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 19, 23, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 19, 23, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 19, 23, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 19, 23, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 19, 23, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 19, 23, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 19, 23, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 19, 23, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 19, 23, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 19, 23, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 19, 23, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 19, 23, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 19, 23, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 19, 23, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 19, 23, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 19, 23, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 19, 23, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 19, 23, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 19, 23, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 19, 23, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 19, 23, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 19, 23, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 19, 23, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 19, 23, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 19, 23, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 19, 23, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 19, 23, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 19, 23, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 19, 23, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 19, 23, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 19, 23, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 19, 23, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 19, 23, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 19, 23, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 19, 23, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 19, 23, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 19, 23, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 19, 23, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 19, 23, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 19, 23, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 19, 23, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 19, 23, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 19, 23, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 19, 23, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 19, 23, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 19, 23, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 19, 23, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 19, 23, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 19, 23, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 19, 23, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 19, 23, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 19, 23, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 19, 23, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 19, 23, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 19, 23, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 19, 23, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 19, 23, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 19, 23, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 19, 23, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 19, 23, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 19, 23, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 19, 23, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 9, 11, 384)   995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 9, 11, 96)    82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 9, 11, 384)  1152        ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 9, 11, 96)   288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 9, 11, 384)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 9, 11, 96)    0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 9, 11, 288)  0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 9, 11, 768)   0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 9, 11, 128)   98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 9, 11, 128)  384         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 9, 11, 128)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 9, 11, 128)   114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 9, 11, 128)  384         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 9, 11, 128)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 9, 11, 128)   98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 9, 11, 128)   114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 9, 11, 128)  384         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 9, 11, 128)  384         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 9, 11, 128)   0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 9, 11, 128)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 9, 11, 128)   114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 9, 11, 128)   114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 9, 11, 128)  384         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 9, 11, 128)  384         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 9, 11, 128)   0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 9, 11, 128)   0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 9, 11, 768)  0           ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 9, 11, 192)   147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 9, 11, 192)   172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 9, 11, 192)   172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 9, 11, 192)   147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 9, 11, 192)  576         ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 9, 11, 192)  576         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 9, 11, 192)  576         ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 9, 11, 192)  576         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 9, 11, 768)   0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 9, 11, 160)   122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 9, 11, 160)  480         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 9, 11, 160)   179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 9, 11, 160)  480         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 9, 11, 160)   122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 9, 11, 160)   179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 9, 11, 160)  480         ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 9, 11, 160)  480         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 9, 11, 160)   179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 9, 11, 160)   179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 9, 11, 160)  480         ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 9, 11, 160)  480         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 9, 11, 768)  0           ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 9, 11, 192)   147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 9, 11, 192)   215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 9, 11, 192)   215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 9, 11, 192)   147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 9, 11, 192)  576         ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 9, 11, 192)  576         ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 9, 11, 192)  576         ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 9, 11, 192)  576         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 9, 11, 768)   0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 9, 11, 160)   122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 9, 11, 160)  480         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 9, 11, 160)   179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 9, 11, 160)  480         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 9, 11, 160)   122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 9, 11, 160)   179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 9, 11, 160)  480         ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 9, 11, 160)  480         ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 9, 11, 160)   179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 9, 11, 160)   179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 9, 11, 160)  480         ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 9, 11, 160)  480         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 9, 11, 160)   0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 9, 11, 768)  0           ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 9, 11, 192)   147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 9, 11, 192)   215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 9, 11, 192)   215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 9, 11, 192)   147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 9, 11, 192)  576         ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 9, 11, 192)  576         ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 9, 11, 192)  576         ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 9, 11, 192)  576         ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 9, 11, 192)   0           ['batch_normalization_59[0][0]']
#
#  mixed6 (Concatenate)           (None, 9, 11, 768)   0           ['activation_50[0][0]',
#                                                                   'activation_53[0][0]',
#                                                                   'activation_58[0][0]',
#                                                                   'activation_59[0][0]']
#
# ...
#
#  batch_normalization_81 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_77[0][0]']
#
#  activation_81 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 4, 5, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 4, 5, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 4, 5, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 4, 5, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 4, 5, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 4, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 4, 5, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 4, 5, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 4, 5, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 4, 5, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 4, 5, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 4, 5, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 4, 5, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 4, 5, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 4, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 4, 5, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 4, 5, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 4, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 4, 5, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 4, 5, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 4, 5, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 4, 5, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 4, 5, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 4, 5, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 4, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 4, 5, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 4, 5, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 4, 5, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 4, 5, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 4, 5, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 4, 5, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 4, 5, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 4, 5, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 4, 5, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 4, 5, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 4, 5, 2048)        21802784
#
#  dropout (Dropout)           (None, 4, 5, 2048)        0
#
#  flatten (Flatten)           (None, 40960)             0
#
#  batch_normalization_94 (Bat  (None, 40960)            163840
#  chNormalization)
#
#  dense (Dense)               (None, 2048)              83888128
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 107,957,028
# Trainable params: 107,840,676
# Non-trainable params: 116,352
# _________________________________________________________________

# %%
### Model Compilation
model.compile(
    optimizer=SGD(learning_rate=0.01), 
    loss = tf.keras.losses.CategoricalCrossentropy(name='loss'), 
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='acc'), 
        tf.keras.metrics.AUC(name='auc'),
        tf.metrics.Precision(name="precision"),
        tf.metrics.Recall(name="recall") 
       ])

# %%
# callbacks used in model to perform well
rop_callback = ReduceLROnPlateau(monitor="val_loss", patience=2)

CALLBACKS = [rop_callback]

# %%
#   declare to run on small gpu create batch sizes of images
valAug = ImageDataGenerator()

#   defining batch size
batch_size = 8

history = model.fit(valAug.flow(X_train, y_train, batch_size=batch_size, shuffle = True),
steps_per_epoch=len(X_train) // batch_size,
validation_data=valAug.flow(x_val, y_val, batch_size=batch_size, shuffle = True),
validation_steps=len(x_test) // batch_size,
epochs= 30,
batch_size=batch_size,
callbacks = CALLBACKS
)
# Out:
# Epoch 1/30
# 1006/1006 [==============================] - 113s 93ms/step - loss: 0.8626 - acc: 0.6801 - auc: 0.8955 - precision: 0.7131 - recall: 0.6319 - val_loss: 0.4058 - val_acc: 0.8282 - val_auc: 0.9703 - val_precision: 0.8589 - val_recall: 0.7943 - lr: 0.0100
# Epoch 2/30
# 1006/1006 [==============================] - 81s 81ms/step - loss: 0.3346 - acc: 0.8694 - auc: 0.9796 - precision: 0.8821 - recall: 0.8557 - val_loss: 0.1386 - val_acc: 0.9537 - val_auc: 0.9966 - val_precision: 0.9599 - val_recall: 0.9427 - lr: 0.0100
# Epoch 3/30
# 1006/1006 [==============================] - 97s 96ms/step - loss: 0.0089 - acc: 0.9976 - auc: 0.9999 - precision: 0.9980 - recall: 0.9974 - val_loss: 0.0137 - val_acc: 0.9960 - val_auc: 1.0000 - val_precision: 0.9960 - val_recall: 0.9955 - lr: 1.0000e-09
# Epoch 24/30
# 1006/1006 [==============================] - 94s 94ms/step - loss: 0.0055 - acc: 0.9985 - auc: 1.0000 - precision: 0.9985 - recall: 0.9983 - val_loss: 0.0181 - val_acc: 0.9955 - val_auc: 0.9996 - val_precision: 0.9955 - val_recall: 0.9955 - lr: 1.0000e-09
# Epoch 25/30
# 1006/1006 [==============================] - 93s 92ms/step - loss: 0.0082 - acc: 0.9973 - auc: 1.0000 - precision: 0.9976 - recall: 0.9966 - val_loss: 0.0163 - val_acc: 0.9950 - val_auc: 0.9996 - val_precision: 0.9955 - val_recall: 0.9950 - lr: 1.0000e-10
# Epoch 26/30
# 1006/1006 [==============================] - 96s 96ms/step - loss: 0.0058 - acc: 0.9986 - auc: 0.9999 - precision: 0.9986 - recall: 0.9983 - val_loss: 0.0188 - val_acc: 0.9950 - val_auc: 0.9996 - val_precision: 0.9950 - val_recall: 0.9945 - lr: 1.0000e-10
# Epoch 27/30
# 1006/1006 [==============================] - 92s 92ms/step - loss: 0.0075 - acc: 0.9979 - auc: 1.0000 - precision: 0.9980 - recall: 0.9978 - val_loss: 0.0110 - val_acc: 0.9970 - val_auc: 1.0000 - val_precision: 0.9970 - val_recall: 0.9970 - lr: 1.0000e-11
# Epoch 28/30
# 1006/1006 [==============================] - 98s 97ms/step - loss: 0.0068 - acc: 0.9978 - auc: 1.0000 - precision: 0.9979 - recall: 0.9974 - val_loss: 0.0169 - val_acc: 0.9955 - val_auc: 0.9996 - val_precision: 0.9955 - val_recall: 0.9955 - lr: 1.0000e-11
# Epoch 29/30
# 1006/1006 [==============================] - 94s 94ms/step - loss: 0.0052 - acc: 0.9984 - auc: 1.0000 - precision: 0.9986 - recall: 0.9984 - val_loss: 0.0157 - val_acc: 0.9955 - val_auc: 0.9996 - val_precision: 0.9955 - val_recall: 0.9955 - lr: 1.0000e-11
# Epoch 30/30
# 1006/1006 [==============================] - 97s 96ms/step - loss: 0.0058 - acc: 0.9981 - auc: 1.0000 - precision: 0.9981 - recall: 0.9980 - val_loss: 0.0141 - val_acc: 0.9965 - val_auc: 0.9996 - val_precision: 0.9965 - val_recall: 0.9965 - lr: 1.0000e-12

# %% [markdown]
# # Model Evaluation

# %%
test_scores = model.evaluate(x_test, y_test, batch_size = 32)

precision = test_scores[3]
recall = test_scores[4]

# Calculate F1-score
f1_score = 2 * (precision * recall) / (precision + recall)

print("Testing Accuracy: \t {0:0.6f} %".format(test_scores[1] * 100))
print("Testing AC: \t\t {0:0.6f} %".format(test_scores[2] * 100))
print("Testing Precision: \t {0:0.6f} %".format(precision * 100))
print("Testing Recall: \t {0:0.6f} %".format(recall * 100))
print("Testing F1-Score: \t {0:0.6f} %".format(f1_score * 100))
# Out:
# 63/63 [==============================] - 3s 50ms/step - loss: 0.0153 - acc: 0.9960 - auc: 0.9996 - precision: 0.9960 - recall: 0.9955
# Testing Accuracy: 	 99.602783 %
# Testing AC: 		 99.962550 %
# Testing Precision: 	 99.602586 %
# Testing Recall: 	 99.553126 %
# Testing F1-Score: 	 99.577850 %

# %% [markdown]
# # Graphs

# %%
plt.plot(history.history['acc'], 'b')
plt.plot(history.history['val_acc'], 'g')
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['loss'], 'b')
plt.plot(history.history['val_loss'], 'g')
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['auc'], 'b')
plt.plot(history.history['val_auc'], 'g')
plt.title("Model AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['precision'], 'b')
plt.plot(history.history['val_precision'], 'g')
plt.title("Model Precision")
plt.xlabel("Epochs")
plt.ylabel("Precision")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['recall'], 'b')
plt.plot(history.history['val_recall'], 'g')
plt.title("Model Recall")
plt.xlabel("Epochs")
plt.ylabel("Recall")
plt.legend(["train", "val"])
plt.show()

# %% [markdown]
# # Test Set Evaluation

# %%
pred_labels = model.predict(x_test, batch_size=32)

def roundoff(arr):
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

# Apply rounding to each set of predicted labels
rounded_pred_labels = [roundoff(labels) for labels in pred_labels]

print(classification_report(y_test, rounded_pred_labels, target_names=CLASSES))
# Out:
# 63/63 [==============================] - 3s 36ms/step
#                    precision    recall  f1-score   support
#
#     Mild-Demented       1.00      1.00      1.00       513
# Moderate-Demented       1.00      1.00      1.00       520
#      Non-Demented       0.99      0.99      0.99       490
# VeryMild-Demented       0.99      0.99      0.99       491
#
#         micro avg       1.00      1.00      1.00      2014
#         macro avg       1.00      1.00      1.00      2014
#      weighted avg       1.00      1.00      1.00      2014
#       samples avg       1.00      1.00      1.00      2014

# %%
pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(y_test, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= CLASSES, yticklabels=CLASSES)

plt.title('Confusion Matrix of Model', fontweight='bold', fontsize=14.0)
plt.xlabel('Predictions', fontweight='bold', fontsize=13)
plt.ylabel('Ground Truth', fontweight='bold', fontsize=13)
plt.tight_layout()
plt.show(ax)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], pred_labels[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), pred_labels.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure()
lw = 2
plt.plot(
    fpr[2],
    tpr[2],
    color="darkorange",
    lw=lw,
    label="ROC curve (area = %0.4f)" % roc_auc[2])

plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic ")
plt.legend(loc="lower right")
plt.show()

# %%
n_classes = 4
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.4f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.4f})".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

for i in range(n_classes):
    plt.plot(
        fpr[i],
        tpr[i],
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.4f})".format(i, roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Some extension of Receiver operating characteristic to multiclass")
plt.legend(loc="lower right")
plt.show()
