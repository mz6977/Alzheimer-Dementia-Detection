# %% [markdown]
# # Imports

# %%
# Standard libraries
import random
from collections import Counter

# External libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from imblearn.combine import SMOTEENN
from sklearn.metrics import auc, classification_report, confusion_matrix, roc_curve
from sklearn.model_selection import train_test_split

# TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Directories

# %%
## Set Path Here before running the code
WORKING_DIRECTORY =  "./data/Dataset"

##  Name of classes 
CLASSES = ['Mild-Demented',
           'Moderate-Demented',
           'Non-Demented',
           'VeryMild-Demented']

# %% [markdown]
# # Load img, Rescale, One Hot Encoding

# %%
X, y = [], []

## Images rescaling
datagen = ImageDataGenerator(rescale=1.0/255.0)

#   Load images by resizing and shuffling randomly
train_dataset = datagen.flow_from_directory(WORKING_DIRECTORY, target_size=(176, 208),batch_size=6400, shuffle=True)

### Seperate Dataset from  Data Genrator
X, y = train_dataset.next()
# Out:
# Found 6426 images belonging to 4 classes.

# %%
samples_before = len(X)
print("Images shape :\t", X.shape)
print("Labels shape :\t", y.shape)
# Out:
# Images shape :	 (6400, 176, 208, 3)
# Labels shape :	 (6400, 4)

# %%
#   Number of samples in classes 
print("Number of samples in each class:\t", sorted(Counter(np.argmax(y, axis=1)).items()))

#   class labels as per indices
print("Classes Names according to index:\t", train_dataset.class_indices)
# Out:
# Number of samples in each class:	 [(0, 895), (1, 90), (2, 3182), (3, 2233)]
# Classes Names according to index:	 {'Mild_Demented': 0, 'Moderate_Demented': 1, 'Non_Demented': 2, 'Very_Mild_Demented': 3}

# %% [markdown]
# # random samples of original dataset

# %%
fig = plt.figure(figsize=(10,8))

rows = 4
columns = 4

for i in range(rows * columns):
    fig.add_subplot(rows, columns, i+1)
    num = random.randint(0, len(X)-1 )
    plt.imshow(X[num])
    plt.axis('off')
    plt.title(CLASSES[(np.argmax(y[num]))], fontsize=8)
plt.axis('off')
plt.show()

# %% [markdown]
# # Apply SmoteENN

# %%
#   reshaping the images to 1D
X = X.reshape(-1, 176 * 208 * 3)

#   Oversampling method to remove imbalance class problem
X, y = SMOTEENN().fit_resample(X, y)

#   reshape images to images size of 208, 176, 3
X = X.reshape(-1, 176, 208, 3)

samples_after = len(X)
print("Number of samples after SMOTEENN :\t", sorted(Counter(np.argmax(y, axis=1)).items()))
# Out:
# Number of samples after SMOTEENN :	 [(0, 3182), (1, 3182), (2, 3025), (3, 3162)]

# %% [markdown]
# # Random samples of generated data

# %%
fig = plt.figure(figsize=(10,8))

rows = 4
columns = 4

for i in range(rows * columns):
    fig.add_subplot(rows, columns, i+1)
    num = random.randint(samples_before, samples_after - 1 )
    plt.imshow(X[num])
    plt.axis('off')
    plt.title(CLASSES[(np.argmax(y[num]))], fontsize=8)
plt.axis('off')
plt.show()

# %% [markdown]
# # Split Dataset

# %%
#   20% split to validation and 80% split to train set
X_train, x_val, y_train, y_val = train_test_split(X,y, test_size = 0.2)

#   20% split to test from 80% of train and 60% remains in train set
X_train, x_test, y_train, y_test = train_test_split(X_train,y_train, test_size = 0.2)

# Number of samples after train test split
print("Number of samples after splitting into Training, validation & test set\n")

print("Train     \t",sorted(Counter(np.argmax(y_train, axis=1)).items()))
print("Validation\t",sorted(Counter(np.argmax(y_val, axis=1)).items()))
print("Test      \t",sorted(Counter(np.argmax(y_test, axis=1)).items()))
# Out:
# Number of samples after splitting into Training, validation & test set
#
# Train     	 [(0, 2017), (1, 2038), (2, 1901), (3, 2076)]
# Validation	 [(0, 666), (1, 616), (2, 619), (3, 610)]
# Test      	 [(0, 499), (1, 528), (2, 505), (3, 476)]

# %%
del X, y       #### NO MORE NEEDED

# %% [markdown]
# # Train Model

# %%
# Load the ResNet50 base model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(176, 208, 3))

# Create a new model on top of the base ResNet50 model
model = Sequential()

# Add the ResNet50 base model
model.add(base_model)

model.add(Dropout(0.10))

model.add(Flatten())

model.add(BatchNormalization())
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.30))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.30))

model.add(Dense(4, activation='softmax'))

base_model.summary()

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 12s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 176, 208, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 182, 214, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 88, 104, 64)  9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 88, 104, 64)  256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 88, 104, 64)  0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 90, 106, 64)  0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 44, 52, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 44, 52, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 44, 52, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 44, 52, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 44, 52, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 44, 52, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 44, 52, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 44, 52, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 44, 52, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 44, 52, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 44, 52, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 44, 52, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 44, 52, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 44, 52, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 44, 52, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 44, 52, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 44, 52, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 44, 52, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 44, 52, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 44, 52, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 44, 52, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 44, 52, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 44, 52, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 44, 52, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 44, 52, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 44, 52, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 44, 52, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 44, 52, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 44, 52, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 44, 52, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 44, 52, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 44, 52, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 44, 52, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 22, 26, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 22, 26, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 22, 26, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 22, 26, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 22, 26, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 22, 26, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 22, 26, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 22, 26, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 22, 26, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 22, 26, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 22, 26, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 22, 26, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 22, 26, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 22, 26, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 22, 26, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 22, 26, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 22, 26, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 22, 26, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 22, 26, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 22, 26, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 22, 26, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 22, 26, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 22, 26, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 22, 26, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 22, 26, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 22, 26, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 22, 26, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 22, 26, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 22, 26, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 22, 26, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 22, 26, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 22, 26, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 22, 26, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 22, 26, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 22, 26, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 22, 26, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 22, 26, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 22, 26, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 22, 26, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 22, 26, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 22, 26, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 22, 26, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 11, 13, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 11, 13, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 11, 13, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 11, 13, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 11, 13, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 11, 13, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 11, 13, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 11, 13, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 11, 13, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 11, 13, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 11, 13, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 11, 13, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 11, 13, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 11, 13, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 11, 13, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 11, 13, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 11, 13, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 11, 13, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 11, 13, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 11, 13, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 11, 13, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 11, 13, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 11, 13, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 11, 13, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 11, 13, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 11, 13, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 11, 13, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 11, 13, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 11, 13, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 11, 13, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 11, 13, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 11, 13, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 11, 13, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 11, 13, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 11, 13, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 11, 13, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 11, 13, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 11, 13, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 11, 13, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 11, 13, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 6, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 6, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 6, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 6, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 6, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 6, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 6, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 6, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 6, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 6, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 6, 7, 2048)        23587712
#
#  dropout (Dropout)           (None, 6, 7, 2048)        0
#
#  flatten (Flatten)           (None, 86016)             0
#
#  batch_normalization (BatchN  (None, 86016)            344064
#  ormalization)
#
#  dense (Dense)               (None, 2048)              176162816
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 202,196,868
# Trainable params: 201,971,716
# Non-trainable params: 225,152
# _________________________________________________________________

# %%
### Model Compilation
model.compile(
    optimizer=SGD(learning_rate=0.01), 
    loss = tf.keras.losses.CategoricalCrossentropy(name='loss'), 
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='acc'), 
        tf.keras.metrics.AUC(name='auc'),
        tf.metrics.Precision(name="precision"),
        tf.metrics.Recall(name="recall") 
       ])

# %%
# callbacks used in model to perform well
rop_callback = ReduceLROnPlateau(monitor="val_loss", patience=2)

CALLBACKS = [rop_callback]

# %%
#   declare to run on small gpu create batch sizes of images
valAug = ImageDataGenerator()

#   defining batch size
batch_size = 8

history = model.fit(valAug.flow(X_train, y_train, batch_size=batch_size, shuffle = True),
steps_per_epoch=len(X_train) // batch_size,
validation_data=valAug.flow(x_val, y_val, batch_size=batch_size, shuffle = True),
validation_steps=len(x_test) // batch_size,
epochs= 30,
batch_size=batch_size,
callbacks = CALLBACKS
)
# Out:
# Epoch 1/30
# 1004/1004 [==============================] - 95s 84ms/step - loss: 0.6509 - acc: 0.7395 - auc: 0.9319 - precision: 0.7719 - recall: 0.7083 - val_loss: 1.1756 - val_acc: 0.5388 - val_auc: 0.8099 - val_precision: 0.5869 - val_recall: 0.5030 - lr: 0.0100
# Epoch 2/30
# 1004/1004 [==============================] - 81s 81ms/step - loss: 0.2248 - acc: 0.9168 - auc: 0.9900 - precision: 0.9226 - recall: 0.9095 - val_loss: 0.1918 - val_acc: 0.9323 - val_auc: 0.9942 - val_precision: 0.9469 - val_recall: 0.9233 - lr: 0.0100
# Epoch 3/30
# 1004/1004 [==============================] - 80s 79ms/step - loss: 0.1205 - acc: 0.9573 - auc: 0.9968 - precision: 0.9599 - recall: 0.9542 - val_loss: 0.2851 - val_acc: 0.8889 - val_auc: 0.9853 - val_precision: 0.9014 - val_recall: 0.8785 - lr: 0.0100
# Epoch 4/30
# 1004/1004 [==============================] - 83s 83ms/step - loss: 0.0848 - acc: 0.9711 - auc: 0.9979 - precision: 0.9726 - recall: 0.9688 - val_loss: 0.1067 - val_acc: 0.9592 - val_auc: 0.9973 - val_precision: 0.9606 - val_recall: 0.9582 - lr: 0.0100
# Epoch 5/30
# 1004/1004 [==============================] - 80s 79ms/step - loss: 0.0798 - acc: 0.9720 - auc: 0.9981 - precision: 0.9732 - recall: 0.9702 - val_loss: 0.1142 - val_acc: 0.9622 - val_auc: 0.9972 - val_precision: 0.9622 - val_recall: 0.9622 - lr: 0.0100
# Epoch 6/30
# 1004/1004 [==============================] - 82s 82ms/step - loss: 0.0552 - acc: 0.9813 - auc: 0.9990 - precision: 0.9819 - recall: 0.9808 - val_loss: 0.1749 - val_acc: 0.9407 - val_auc: 0.9934 - val_precision: 0.9433 - val_recall: 0.9363 - lr: 0.0100
# Epoch 7/30
# 1004/1004 [==============================] - 81s 80ms/step - loss: 0.0232 - acc: 0.9923 - auc: 0.9997 - precision: 0.9928 - recall: 0.9918 - val_loss: 0.0170 - val_acc: 0.9940 - val_auc: 1.0000 - val_precision: 0.9940 - val_recall: 0.9940 - lr: 1.0000e-03
# Epoch 8/30
# 1004/1004 [==============================] - 83s 82ms/step - loss: 0.0171 - acc: 0.9949 - auc: 0.9999 - precision: 0.9953 - recall: 0.9944 - val_loss: 0.0094 - val_acc: 0.9980 - val_auc: 1.0000 - val_precision: 0.9985 - val_recall: 0.9980 - lr: 1.0000e-03
# Epoch 9/30
# 1004/1004 [==============================] - 83s 82ms/step - loss: 0.0120 - acc: 0.9968 - auc: 0.9999 - precision: 0.9969 - recall: 0.9964 - val_loss: 0.0115 - val_acc: 0.9960 - val_auc: 1.0000 - val_precision: 0.9960 - val_recall: 0.9960 - lr: 1.0000e-03
# Epoch 10/30
# 1004/1004 [==============================] - 83s 83ms/step - loss: 0.0103 - acc: 0.9970 - auc: 1.0000 - precision: 0.9975 - recall: 0.9970 - val_loss: 0.0093 - val_acc: 0.9970 - val_auc: 1.0000 - val_precision: 0.9970 - val_recall: 0.9970 - lr: 1.0000e-03
# Epoch 11/30
# 1004/1004 [==============================] - 86s 85ms/step - loss: 0.0090 - acc: 0.9979 - auc: 0.9999 - precision: 0.9980 - recall: 0.9978 - val_loss: 0.0078 - val_acc: 0.9980 - val_auc: 1.0000 - val_precision: 0.9980 - val_recall: 0.9980 - lr: 1.0000e-04
# Epoch 12/30
# 1004/1004 [==============================] - 87s 87ms/step - loss: 0.0102 - acc: 0.9959 - auc: 1.0000 - precision: 0.9960 - recall: 0.9955 - val_loss: 0.0101 - val_acc: 0.9970 - val_auc: 1.0000 - val_precision: 0.9970 - val_recall: 0.9970 - lr: 1.0000e-04
# Epoch 13/30
# 1004/1004 [==============================] - 86s 86ms/step - loss: 0.0082 - acc: 0.9976 - auc: 1.0000 - precision: 0.9976 - recall: 0.9975 - val_loss: 0.0097 - val_acc: 0.9975 - val_auc: 1.0000 - val_precision: 0.9975 - val_recall: 0.9975 - lr: 1.0000e-04
# Epoch 14/30
# 1004/1004 [==============================] - 88s 87ms/step - loss: 0.0071 - acc: 0.9980 - auc: 1.0000 - precision: 0.9983 - recall: 0.9980 - val_loss: 0.0101 - val_acc: 0.9970 - val_auc: 1.0000 - val_precision: 0.9970 - val_recall: 0.9970 - lr: 1.0000e-05
# Epoch 15/30
# 1004/1004 [==============================] - 84s 84ms/step - loss: 0.0076 - acc: 0.9984 - auc: 1.0000 - precision: 0.9985 - recall: 0.9980 - val_loss: 0.0080 - val_acc: 0.9975 - val_auc: 1.0000 - val_precision: 0.9975 - val_recall: 0.9975 - lr: 1.0000e-05
# Epoch 16/30
# 1004/1004 [==============================] - 86s 86ms/step - loss: 0.0081 - acc: 0.9971 - auc: 1.0000 - precision: 0.9976 - recall: 0.9969 - val_loss: 0.0088 - val_acc: 0.9980 - val_auc: 1.0000 - val_precision: 0.9980 - val_recall: 0.9980 - lr: 1.0000e-06
# Epoch 17/30
# 1004/1004 [==============================] - 88s 87ms/step - loss: 0.0057 - acc: 0.9989 - auc: 1.0000 - precision: 0.9989 - recall: 0.9985 - val_loss: 0.0098 - val_acc: 0.9970 - val_auc: 1.0000 - val_precision: 0.9970 - val_recall: 0.9970 - lr: 1.0000e-06
# Epoch 18/30
# 1004/1004 [==============================] - 86s 85ms/step - loss: 0.0117 - acc: 0.9964 - auc: 1.0000 - precision: 0.9966 - recall: 0.9963 - val_loss: 0.0093 - val_acc: 0.9970 - val_auc: 1.0000 - val_precision: 0.9970 - val_recall: 0.9970 - lr: 1.0000e-07
# Epoch 19/30
# 1004/1004 [==============================] - 90s 89ms/step - loss: 0.0085 - acc: 0.9974 - auc: 0.9999 - precision: 0.9975 - recall: 0.9973 - val_loss: 0.0104 - val_acc: 0.9965 - val_auc: 1.0000 - val_precision: 0.9965 - val_recall: 0.9965 - lr: 1.0000e-07
# Epoch 20/30
# 1004/1004 [==============================] - 88s 88ms/step - loss: 0.0062 - acc: 0.9980 - auc: 1.0000 - precision: 0.9983 - recall: 0.9978 - val_loss: 0.0106 - val_acc: 0.9970 - val_auc: 1.0000 - val_precision: 0.9970 - val_recall: 0.9970 - lr: 1.0000e-08
# Epoch 21/30
# 1004/1004 [==============================] - 82s 82ms/step - loss: 0.0103 - acc: 0.9973 - auc: 0.9999 - precision: 0.9976 - recall: 0.9971 - val_loss: 0.0101 - val_acc: 0.9970 - val_auc: 1.0000 - val_precision: 0.9970 - val_recall: 0.9970 - lr: 1.0000e-08
# Epoch 22/30
# 1004/1004 [==============================] - 83s 82ms/step - loss: 0.0097 - acc: 0.9966 - auc: 1.0000 - precision: 0.9969 - recall: 0.9966 - val_loss: 0.0097 - val_acc: 0.9975 - val_auc: 1.0000 - val_precision: 0.9975 - val_recall: 0.9975 - lr: 1.0000e-09
# Epoch 23/30
# 1004/1004 [==============================] - 81s 81ms/step - loss: 0.0066 - acc: 0.9983 - auc: 1.0000 - precision: 0.9983 - recall: 0.9981 - val_loss: 0.0079 - val_acc: 0.9980 - val_auc: 1.0000 - val_precision: 0.9980 - val_recall: 0.9980 - lr: 1.0000e-09
# Epoch 24/30
# 1004/1004 [==============================] - 80s 80ms/step - loss: 0.0073 - acc: 0.9979 - auc: 1.0000 - precision: 0.9979 - recall: 0.9979 - val_loss: 0.0084 - val_acc: 0.9975 - val_auc: 1.0000 - val_precision: 0.9975 - val_recall: 0.9975 - lr: 1.0000e-10
# Epoch 25/30
# 1004/1004 [==============================] - 83s 83ms/step - loss: 0.0101 - acc: 0.9970 - auc: 0.9999 - precision: 0.9974 - recall: 0.9970 - val_loss: 0.0098 - val_acc: 0.9970 - val_auc: 1.0000 - val_precision: 0.9970 - val_recall: 0.9970 - lr: 1.0000e-10
# Epoch 26/30
# 1004/1004 [==============================] - 82s 82ms/step - loss: 0.0077 - acc: 0.9974 - auc: 1.0000 - precision: 0.9974 - recall: 0.9971 - val_loss: 0.0090 - val_acc: 0.9975 - val_auc: 1.0000 - val_precision: 0.9975 - val_recall: 0.9975 - lr: 1.0000e-11
# Epoch 27/30
# 1004/1004 [==============================] - 80s 80ms/step - loss: 0.0067 - acc: 0.9980 - auc: 1.0000 - precision: 0.9983 - recall: 0.9978 - val_loss: 0.0095 - val_acc: 0.9970 - val_auc: 1.0000 - val_precision: 0.9970 - val_recall: 0.9970 - lr: 1.0000e-11
# Epoch 28/30
# 1004/1004 [==============================] - 79s 79ms/step - loss: 0.0077 - acc: 0.9975 - auc: 1.0000 - precision: 0.9976 - recall: 0.9975 - val_loss: 0.0065 - val_acc: 0.9980 - val_auc: 1.0000 - val_precision: 0.9980 - val_recall: 0.9980 - lr: 1.0000e-12
# Epoch 29/30
# 1004/1004 [==============================] - 82s 82ms/step - loss: 0.0082 - acc: 0.9975 - auc: 1.0000 - precision: 0.9979 - recall: 0.9973 - val_loss: 0.0113 - val_acc: 0.9965 - val_auc: 1.0000 - val_precision: 0.9965 - val_recall: 0.9965 - lr: 1.0000e-12
# Epoch 30/30
# 1004/1004 [==============================] - 81s 80ms/step - loss: 0.0084 - acc: 0.9964 - auc: 1.0000 - precision: 0.9965 - recall: 0.9964 - val_loss: 0.0105 - val_acc: 0.9965 - val_auc: 1.0000 - val_precision: 0.9965 - val_recall: 0.9965 - lr: 1.0000e-12

# %% [markdown]
# # Model Evaluation

# %%
test_scores = model.evaluate(x_test, y_test, batch_size = 32)

precision = test_scores[3]
recall = test_scores[4]

# Calculate F1-score
f1_score = 2 * (precision * recall) / (precision + recall)

print("Testing Accuracy: \t {0:0.6f} %".format(test_scores[1] * 100))
print("Testing AC: \t\t {0:0.6f} %".format(test_scores[2] * 100))
print("Testing Precision: \t {0:0.6f} %".format(precision * 100))
print("Testing Recall: \t {0:0.6f} %".format(recall * 100))
print("Testing F1-Score: \t {0:0.6f} %".format(f1_score * 100))
# Out:
# 63/63 [==============================] - 3s 49ms/step - loss: 0.0126 - acc: 0.9950 - auc: 0.9997 - precision: 0.9950 - recall: 0.9950
# Testing Accuracy: 	 99.501991 %
# Testing AC: 		 99.972272 %
# Testing Precision: 	 99.501991 %
# Testing Recall: 	 99.501991 %
# Testing F1-Score: 	 99.501991 %

# %% [markdown]
# # Graphs

# %%
plt.plot(history.history['acc'], 'b')
plt.plot(history.history['val_acc'], 'g')
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['loss'], 'b')
plt.plot(history.history['val_loss'], 'g')
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['auc'], 'b')
plt.plot(history.history['val_auc'], 'g')
plt.title("Model AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['precision'], 'b')
plt.plot(history.history['val_precision'], 'g')
plt.title("Model Precision")
plt.xlabel("Epochs")
plt.ylabel("Precision")
plt.legend(["train", "val"])
plt.show()

# %%
plt.plot(history.history['recall'], 'b')
plt.plot(history.history['val_recall'], 'g')
plt.title("Model Recall")
plt.xlabel("Epochs")
plt.ylabel("Recall")
plt.legend(["train", "val"])
plt.show()

# %% [markdown]
# # Test Set Evaluation

# %%
pred_labels = model.predict(x_test, batch_size=32)

def roundoff(arr):
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

# Apply rounding to each set of predicted labels
rounded_pred_labels = [roundoff(labels) for labels in pred_labels]

print(classification_report(y_test, rounded_pred_labels, target_names=CLASSES))
# Out:
# 63/63 [==============================] - 3s 31ms/step
#                    precision    recall  f1-score   support
#
#     Mild-Demented       1.00      1.00      1.00       499
# Moderate-Demented       1.00      1.00      1.00       528
#      Non-Demented       0.99      0.99      0.99       505
# VeryMild-Demented       0.99      0.99      0.99       476
#
#         micro avg       1.00      1.00      1.00      2008
#         macro avg       0.99      0.99      0.99      2008
#      weighted avg       1.00      1.00      1.00      2008
#       samples avg       1.00      1.00      1.00      2008

# %%
pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(y_test, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= CLASSES, yticklabels=CLASSES)

plt.title('Confusion Matrix of Model', fontweight='bold', fontsize=14.0)
plt.xlabel('Predictions', fontweight='bold', fontsize=13)
plt.ylabel('Ground Truth', fontweight='bold', fontsize=13)
plt.tight_layout()
plt.show(ax)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], pred_labels[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), pred_labels.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure()
lw = 2
plt.plot(
    fpr[2],
    tpr[2],
    color="darkorange",
    lw=lw,
    label="ROC curve (area = %0.4f)" % roc_auc[2])

plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic ")
plt.legend(loc="lower right")
plt.show()

# %%
n_classes = 4
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure()
plt.plot(
    fpr["micro"],
    tpr["micro"],
    label="micro-average ROC curve (area = {0:0.4f})".format(roc_auc["micro"]),
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label="macro-average ROC curve (area = {0:0.4f})".format(roc_auc["macro"]),
    color="navy",
    linestyle=":",
    linewidth=4,
)

for i in range(n_classes):
    plt.plot(
        fpr[i],
        tpr[i],
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.4f})".format(i, roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Some extension of Receiver operating characteristic to multiclass")
plt.legend(loc="lower right")
plt.show()
